# %%
import scienceplots
import matplotlib.pyplot as plt
import numpy as np
from lmfit import Model
import os

from blume.process import read, compute, plot_file, exact_m
from blume.run import ModelParameters, Results
from blume.model.post_props import Prop

plt.style.use("science")
plt.rcParams["text.usetex"] = True

T_c = 2 / np.log(1 + np.sqrt(2))

# %% [markdown]
# # Data collapse for finite system

# %%
plt.figure(figsize= (7, 5))

for L in [10000, 5000, 1000, 500]:
    data = read("30-04 02:25", f"max_steps{L-4}")
    mags = compute(Prop.m, data)
    reduced_temps = [(T-T_c)/T_c for T in data["temperatures"]]
    y = [m*(L**(1/8)) for m in mags]  
    x = [t*L for t in reduced_temps]


    plt.plot(x, y, "x", label=f"L={L}")

plt.xlabel(r"$t \cdot L^{1/ \nu}$", fontsize=13)
plt.ylabel(r"$m(t, L) \cdot L^{\beta / \nu}$", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# Data collapse for $\chi = 18$ and stepsize = 0.0001

# %%
plt.figure(figsize= (7, 5))

for L in [500, 1000, 2000, 4500]:
    data = read("30-04 15:14", f"max_steps{L-4}")
    mags = compute(Prop.m, data)
    reduced_temps = [(T-T_c)/T_c for T in data["temperatures"]]
    y = [m*(L**(1/8)) for m in mags]  
    x = [t*L for t in reduced_temps]


    plt.plot(x, y, "x", label=f"L={L}")

plt.xlabel(r"$t \cdot L^{1/ \nu}$", fontsize=13)
plt.ylabel(r"$m(t, L) \cdot L^{\beta / \nu}$", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# Data collapse for $\chi = 16$ and stepsize = 0.001

# %%
results = Results(varying_param="max_steps", range=[96, 196, 396, 896])
params = ModelParameters(chi = 32, T_range=(2.25, 2.29), step=0.001, tol=1e-15, b_c=True, fixed=True)
results.get(params)
# Out:
# max_steps=96: 100%|██████████| 41/41 [00:08<00:00,  4.68it/s]
# Saving data in folder: '01-05 13:34'
# Done
# max_steps=196: 100%|██████████| 41/41 [00:18<00:00,  2.24it/s]
# Saving data in folder: '01-05 13:34'
# Done
# max_steps=396: 100%|██████████| 41/41 [00:37<00:00,  1.09it/s]
# Saving data in folder: '01-05 13:34'
# Done
# max_steps=896: 100%|██████████| 41/41 [01:25<00:00,  2.08s/it]
# Saving data in folder: '01-05 13:34'
# Done

# %%
plt.figure(figsize= (7, 5))

for L in [100, 200, 400, 900]:
    data = read("01-05 13:34", f"max_steps{L-4}")
    mags = compute(Prop.m, data)
    reduced_temps = [(T-T_c)/T_c for T in data["temperatures"]]
    y = [m*(L**(1/8)) for m in mags]  
    x = [t*L for t in reduced_temps]


    plt.plot(x, y, "x", label=f"L={L}")

plt.xlabel(r"$t \cdot L^{1/ \nu}$", fontsize=13)
plt.ylabel(r"$m(t, L) \cdot L^{\beta / \nu}$", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# Data collapse for $\chi = 32$ and stepsize = 0.001

# %%
results = Results(varying_param="max_steps", range=[10, 20, 40, 80])
params = ModelParameters(chi = 64, T_range=(2.25, 2.29), step=0.001, tol=1e-15, b_c=True, fixed=True)
results.get(params)
# Out:
# max_steps=10: 100%|██████████| 41/41 [00:04<00:00,  8.41it/s]
# Saving data in folder: '01-05 13:42'
# Done
# max_steps=20: 100%|██████████| 41/41 [00:16<00:00,  2.52it/s]
# Saving data in folder: '01-05 13:42'
# Done
# max_steps=40: 100%|██████████| 41/41 [00:33<00:00,  1.22it/s]
# Saving data in folder: '01-05 13:42'
# Done
# max_steps=80: 100%|██████████| 41/41 [01:16<00:00,  1.87s/it]
# Saving data in folder: '01-05 13:42'
# Done

# %%
plt.figure(figsize= (7, 5))

for L in [14, 24, 44, 84]:
    data = read("01-05 13:42", f"max_steps{L-4}")
    mags = compute(Prop.m, data)
    reduced_temps = [(T-T_c)/T_c for T in data["temperatures"]]
    y = [m*(L**(1/8)) for m in mags]  
    x = [t*L for t in reduced_temps]


    plt.plot(x, y, "x", label=f"L={L}")

plt.xlabel(r"$t \cdot L^{1/ \nu}$", fontsize=13)
plt.ylabel(r"$m(t, L) \cdot L^{\beta / \nu}$", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# # Data collapse for infinite system

# %%
results = Results(varying_param="chi", range=[12, 16, 24])
params = ModelParameters(T_range=(2.2, 2.3), step=0.001, tol=1e-9)
results.get(params)
# Out:
# chi=12: 100%|██████████| 100/100 [02:59<00:00,  1.79s/it]
# Saving data in folder: '01-05 14:55'
# Done
# chi=16: 100%|██████████| 100/100 [03:46<00:00,  2.27s/it]
# Saving data in folder: '01-05 14:55'
# Done
# chi=24: 100%|██████████| 100/100 [07:16<00:00,  4.37s/it]
# Saving data in folder: '01-05 14:55'
# Done

# %%
params.T_range = [T_c]
results.get(params)
# Out:
# chi=12: 100%|██████████| 1/1 [00:07<00:00,  7.77s/it]
# Saving data in folder: '01-05 14:30'
# Done
# chi=16: 100%|██████████| 1/1 [00:13<00:00, 13.83s/it]
# Saving data in folder: '01-05 14:30'
# Done
# chi=24: 100%|██████████| 1/1 [00:49<00:00, 49.46s/it]
# Saving data in folder: '01-05 14:30'
# Done

# %%
plt.figure(figsize= (7, 5))

for chi in [12, 16, 24]:
    data = read("01-05 14:55", f"chi{chi}")
    data_T_c = read("01-05 14:30", f"chi{chi}")
    mags = compute(Prop.m, data)
    xi = compute(Prop.xi, data_T_c)[0]
    reduced_temps = [(T-T_c)/T_c for T in data["temperatures"]]
    y = [m*(xi**(1/8)) for m in mags]  
    x = [t*xi for t in reduced_temps]


    plt.plot(x, y, "x", label=f"$\chi={chi}$")

plt.xlabel(r"$t \cdot (\xi^{eff}_{\chi})^{1/ \nu}$", fontsize=13)
plt.ylabel(r"$m(t, \chi) \cdot (\xi^{eff}_{\chi})^{\beta/ \nu}$", fontsize=13)
plt.legend()
plt.xlim(-3, 3)
plt.show()

# %% [markdown]
# Data collapse for $L = \infty$ and stepsize = 0.001
